# %% [markdown]
# # LoRA Train UI: SD-Trainer
#
# LoRA Training UI By [Akegarasu](https://github.com/Akegarasu)
# User Guide：https://github.com/Akegarasu/lora-scripts/blob/main/README.md
#
# LoRA 训练 By [秋葉aaaki@bilibili](https://space.bilibili.com/12566101)
# 使用方法：https://www.bilibili.com/read/cv24050162/

# %% [markdown]
# ### Run | 运行

# %%
import sys
# !export HF_HOME=huggingface && $sys.executable gui.py --host 0.0.0.0

# %% [markdown]
# ## Update | 更新

# %% [markdown]
# ### Github

# %%
# No Git submodules remain; pull application code only.
# !git pull

# %% [markdown]
# ### 国内镜像加速

# %%
# Legacy notebook helper. Prefer portable Update-Next-Trainer.bat / git pull on origin.
# No Git submodules remain on main; gitconfig-cn only has optional kohya mirror rewrites.
# !export GIT_CONFIG_GLOBAL=./assets/gitconfig-cn && export GIT_TERMINAL_PROMPT=false && git pull
